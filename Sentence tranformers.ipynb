# %%
from transformers import AutoTokenizer, AutoModel
import torch

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask

# %%
# !pip install  sentence-transformers
# Out:
# ...
#   Using cached sentence_transformers-1.1.0-py3-none-any.whl
# ...

# %%
#Sentences we want sentence embeddings for
sentences = ['This framework generates embeddings for each input sentence',
             'Sentences are passed as a list of string.',
             'The quick brown fox jumps over the lazy dog.']

# %%
#Load AutoModel from huggingface model repository
# tokenizer = AutoTokenizer.from_pretrained("paraphrase-distilroberta-base-v1")
model = AutoModel.from_pretrained(r"C:\Users\1686110\Documents\Nokia\sentence-transformers-master\sentence_transformers\models")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-052ad83e1a82> in <module>
#       1 #Load AutoModel from huggingface model repository
#       2 # tokenizer = AutoTokenizer.from_pretrained("paraphrase-distilroberta-base-v1")
# ----> 3 model = AutoModel.from_pretrained(r"C:\Users\1686110\Documents\Nokia\sentence-transformers-master\sentence_transformers\models")
#
# ~\Anaconda3\lib\site-packages\transformers\models\auto\auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     352         kwargs["_from_auto"] = True
#     353         if not isinstance(config, PretrainedConfig):
# --> 354             config, kwargs = AutoConfig.from_pretrained(
#     355                 pretrained_model_name_or_path, return_unused_kwargs=True, **kwargs
#     356             )
#
# ...

# %%
import nltk
from nltk.stem import PorterStemmer
ps = PorterStemmer()

sentence = "Machine Learning is cool"

for word in sentence.split():
  print(ps.stem(word))
# Out:
# machin
# learn
# is
# cool

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('paraphrase-distilroberta-base-v1')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...

# %%
from sentence_transformers import SentenceTransformer

# %%
import nltk
from nltk.tokenize import word_tokenize
import numpy as np
import pandas as pd
import re

# %%
stop_words = nltk.corpus.stopwords.words('english')

# %%
pattern = re.compile(r'[\W|_]+')

# %%
model = SentenceTransformer('paraphrase-distilroberta-base-v1')

# %%
for line in text:
    print(line)
    filtered_string = re.sub(pattern, " ", line)
    words = filtered_string.lower().split(' ')
    for word in stop_words:
        while word in words:
            words.remove(word)
    sentence = ' '.join(words)
    sentences.append(sentence)

# %%
line = "richard is great"
filtered_string = re.sub(pattern, " ", line)
words = filtered_string.lower().split(' ')
for word in stop_words:
    while word in words:
        words.remove(word)
sentence = ' '.join(words)

# %%
sentence
# Out:
# 'richard great'

# %%
#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentence)

# %%
a = np.asarray(embeddings)

# %%
a
# Out:
# array([-2.17830986e-01, -2.13377625e-01,  2.13105440e-01,  3.01201250e-02,
#         2.02578753e-01,  2.64881819e-01, -7.80529827e-02,  4.49486643e-01,
#         1.15738884e-01, -5.63774407e-02,  1.80821002e-01,  3.67838264e-01,
#        -6.84874058e-02,  4.25232887e-01, -6.07923567e-01, -2.47354835e-01,
#         7.21630216e-01, -8.17262158e-02,  4.91449311e-02, -1.32634519e-02,
#         9.12795514e-02, -6.73278272e-02, -5.02765179e-03, -1.73470721e-01,
#         4.13174927e-01,  7.41255295e-04,  6.07819498e-01, -2.50470340e-01,
#         5.72296157e-02, -5.27229369e-01, -5.54706633e-01,  3.81233513e-01,
#        -3.20299327e-01,  5.25435619e-02, -4.71313864e-01,  3.45207065e-01,
#        -5.70718050e-02, -6.88094497e-02,  1.25579044e-01, -7.22122490e-02,
#         7.45521933e-02,  3.53568465e-01,  2.32832074e-01,  4.09686714e-01,
#        -6.62891846e-03, -2.33513355e-01, -3.08273435e-01, -3.03018242e-01,
# ...

# %%
a = a.tolist()

# %%
a
# Out:
# [-0.21783098578453064,
#  -0.21337762475013733,
#  0.2131054401397705,
#  0.03012012504041195,
#  0.20257875323295593,
#  0.26488181948661804,
#  -0.07805298268795013,
#  0.449486643075943,
#  0.1157388836145401,
#  -0.05637744069099426,
#  0.1808210015296936,
#  0.3678382635116577,
#  -0.06848740577697754,
#  0.4252328872680664,
#  -0.6079235672950745,
#  -0.24735483527183533,
#  0.7216302156448364,
#  -0.08172621577978134,
#  0.0491449311375618,
#  -0.013263451866805553,
#  0.09127955138683319,
#  -0.0673278272151947,
#  -0.005027651786804199,
#  -0.17347072064876556,
#  0.41317492723464966,
#  0.0007412552949972451,
#  0.6078194975852966,
#  -0.2504703402519226,
#  0.05722961574792862,
#  -0.527229368686676,
#  -0.5547066330909729,
#  0.3812335133552551,
#  -0.32029932737350464,
#  0.05254356190562248,
#  -0.47131386399269104,
#  0.3452070653438568,
#  -0.057071805000305176,
#  -0.06880944967269897,
#  0.12557904422283173,
#  -0.07221224904060364,
#  0.07455219328403473,
# ...

# %%
embeddings
# Out:
# array([ 2.20683604e-01, -2.28192225e-01,  2.11259112e-01,  2.83978552e-01,
#         2.65582711e-01, -7.24684745e-02, -3.06555361e-01,  3.80259782e-01,
#        -2.67554075e-01, -2.43743315e-01,  2.34260052e-01, -3.67266953e-01,
#         1.26402304e-01, -1.43376720e+00,  6.91492915e-01, -6.57519877e-01,
#         2.13325649e-01, -4.57576752e-01, -2.16175392e-01, -2.23557875e-01,
#         3.11906007e-03,  3.56404483e-03, -2.06359133e-01,  2.36219779e-01,
#        -1.43238276e-01,  5.41333370e-02,  6.03367053e-02, -2.99193352e-01,
#        -4.49805021e-01, -1.51984245e-01, -2.55189896e-01, -3.43020298e-02,
#        -6.27282681e-03,  3.65476534e-02, -4.22202379e-01, -2.53691822e-01,
#         1.23209633e-01,  9.05792490e-02,  6.53968304e-02, -2.29106277e-01,
#        -2.15551034e-01, -5.40548205e-01, -4.66996506e-02,  2.43578814e-02,
#         1.63922999e-02, -6.08890597e-03,  1.37660936e-01, -2.31432945e-01,
# ...
